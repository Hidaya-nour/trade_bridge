# %% [markdown]
# # Demand Forecasting Model Training
#
# This notebook trains a machine learning model for demand forecasting using the prepared dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib

# Load the prepared dataset
df = pd.read_csv('../data/processed/demand_dataset.csv')
print("Dataset loaded. Shape:", df.shape)

# %%
# Prepare features and target
# Drop non-numeric or unnecessary columns
features = df.drop(['demand', 'date', 'retailer_id', 'product_id'], axis=1, errors='ignore')
target = df['demand']

# Handle categorical columns if any
features = pd.get_dummies(features, drop_first=True)

print("Features shape:", features.shape)
print("Target shape:", target.shape)

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

print("Training set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)

# %%
# Train a Random Forest model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

print("Model trained.")

# %%
# Evaluate the model
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")

# %%
# Save the model
joblib.dump(model, '../models/demand_forecasting_model.pkl')
print("Model saved to ../models/demand_forecasting_model.pkl")
